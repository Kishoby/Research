# %% [markdown]
# <a href="https://colab.research.google.com/github/Kishoby/Research/blob/main/Analysis/EDA2_Preprocessing_231125.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
path="/content/drive/MyDrive/Research/GlobalWeatherRepository (1).csv"
df=pd.read_csv(path)
df.head(5)
# Out:
#        country     location_name  latitude  longitude        timezone  \
# 0  Afghanistan             Kabul     34.52      69.18      Asia/Kabul
# 1      Albania            Tirana     41.33      19.82   Europe/Tirane
# 2      Algeria           Algiers     36.76       3.05  Africa/Algiers
# 3      Andorra  Andorra La Vella     42.50       1.52  Europe/Andorra
# 4       Angola            Luanda     -8.84      13.23   Africa/Luanda
#
#    last_updated_epoch     last_updated  temperature_celsius  \
# 0          1715849100  5/16/2024 13:15                 26.6
# 1          1715849100  5/16/2024 10:45                 19.0
# 2          1715849100   5/16/2024 9:45                 23.0
# 3          1715849100  5/16/2024 10:45                  6.3
# 4          1715849100   5/16/2024 9:45                 26.0
#
#    temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 0                    79.8  Partly Cloudy  ...                8.4
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106013 entries, 0 to 106012
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   country                       106013 non-null  object
#  1   location_name                 106013 non-null  object
#  2   latitude                      106013 non-null  float64
#  3   longitude                     106013 non-null  float64
#  4   timezone                      106013 non-null  object
#  5   last_updated_epoch            106013 non-null  int64
#  6   last_updated                  106013 non-null  object
#  7   temperature_celsius           106013 non-null  float64
#  8   temperature_fahrenheit        106013 non-null  float64
#  9   condition_text                106013 non-null  object
#  10  wind_mph                      106013 non-null  float64
#  11  wind_kph                      106013 non-null  float64
# ...

# %%
df.isnull().sum()
(df.isnull().sum()/len(df))*100
# Out:
# country                         0.0
# location_name                   0.0
# latitude                        0.0
# longitude                       0.0
# timezone                        0.0
# last_updated_epoch              0.0
# last_updated                    0.0
# temperature_celsius             0.0
# temperature_fahrenheit          0.0
# condition_text                  0.0
# wind_mph                        0.0
# wind_kph                        0.0
# wind_degree                     0.0
# wind_direction                  0.0
# pressure_mb                     0.0
# pressure_in                     0.0
# precip_mm                       0.0
# precip_in                       0.0
# humidity                        0.0
# cloud                           0.0
# feels_like_celsius              0.0
# feels_like_fahrenheit           0.0
# visibility_km                   0.0
# visibility_miles                0.0
# uv_index                        0.0
# gust_mph                        0.0
# ...

# %%
constant_cols = [col for col in df.columns if df[col].nunique() == 1]
constant_cols
# Out:
# []

# %%
df=df.drop(constant_cols, axis=1)

# %%
df.dtypes
# Out:
# country                          object
# location_name                    object
# latitude                        float64
# longitude                       float64
# timezone                         object
# last_updated_epoch                int64
# last_updated                     object
# temperature_celsius             float64
# temperature_fahrenheit          float64
# condition_text                   object
# wind_mph                        float64
# wind_kph                        float64
# wind_degree                       int64
# wind_direction                   object
# pressure_mb                       int64
# pressure_in                     float64
# precip_mm                       float64
# precip_in                       float64
# humidity                          int64
# cloud                             int64
# feels_like_celsius              float64
# feels_like_fahrenheit           float64
# visibility_km                   float64
# ...

# %%
df[(df['temperature_celsius'] < -100) | (df['temperature_celsius'] > 60)]
# Out:
# Empty DataFrame
# Columns: [country, location_name, latitude, longitude, timezone, last_updated_epoch, last_updated, temperature_celsius, temperature_fahrenheit, condition_text, wind_mph, wind_kph, wind_degree, wind_direction, pressure_mb, pressure_in, precip_mm, precip_in, humidity, cloud, feels_like_celsius, feels_like_fahrenheit, visibility_km, visibility_miles, uv_index, gust_mph, gust_kph, air_quality_Carbon_Monoxide, air_quality_Ozone, air_quality_Nitrogen_dioxide, air_quality_Sulphur_dioxide, air_quality_PM2.5, air_quality_PM10, air_quality_us-epa-index, air_quality_gb-defra-index, sunrise, sunset, moonrise, moonset, moon_phase, moon_illumination]
# Index: []
#
# [0 rows x 41 columns]

# %%
df[(df['humidity'] < 0) | (df['humidity'] > 100)]
# Out:
# Empty DataFrame
# Columns: [country, location_name, latitude, longitude, timezone, last_updated_epoch, last_updated, temperature_celsius, temperature_fahrenheit, condition_text, wind_mph, wind_kph, wind_degree, wind_direction, pressure_mb, pressure_in, precip_mm, precip_in, humidity, cloud, feels_like_celsius, feels_like_fahrenheit, visibility_km, visibility_miles, uv_index, gust_mph, gust_kph, air_quality_Carbon_Monoxide, air_quality_Ozone, air_quality_Nitrogen_dioxide, air_quality_Sulphur_dioxide, air_quality_PM2.5, air_quality_PM10, air_quality_us-epa-index, air_quality_gb-defra-index, sunrise, sunset, moonrise, moonset, moon_phase, moon_illumination]
# Index: []
#
# [0 rows x 41 columns]

# %%
df[df['wind_kph'] < 0]
# Out:
# Empty DataFrame
# Columns: [country, location_name, latitude, longitude, timezone, last_updated_epoch, last_updated, temperature_celsius, temperature_fahrenheit, condition_text, wind_mph, wind_kph, wind_degree, wind_direction, pressure_mb, pressure_in, precip_mm, precip_in, humidity, cloud, feels_like_celsius, feels_like_fahrenheit, visibility_km, visibility_miles, uv_index, gust_mph, gust_kph, air_quality_Carbon_Monoxide, air_quality_Ozone, air_quality_Nitrogen_dioxide, air_quality_Sulphur_dioxide, air_quality_PM2.5, air_quality_PM10, air_quality_us-epa-index, air_quality_gb-defra-index, sunrise, sunset, moonrise, moonset, moon_phase, moon_illumination]
# Index: []
#
# [0 rows x 41 columns]

# %%
df[(df['pressure_mb'] < 850) | (df['pressure_mb'] > 1100)]
# Out:
#         country location_name  latitude  longitude             timezone  \
# 49769  Honduras   Tegucigalpa   14.1000   -87.2167  America/Tegucigalpa
# 52114      Iran        Tehran   35.7261    51.3304          Asia/Tehran
#
#        last_updated_epoch    last_updated  temperature_celsius  \
# 49769          1738062000  1/28/2025 5:00                 19.1
# 52114          1739097000  2/9/2025 14:00                  2.1
#
#        temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 49769                    66.4  Partly cloudy  ...               6.66
# 52114                    35.8       Overcast  ...              51.43
#
#        air_quality_PM10  air_quality_us-epa-index air_quality_gb-defra-index  \
# 49769             8.140                         1                          1
# 52114            52.725                         3                          6
#
#        sunrise   sunset  moonrise  moonset       moon_phase  moon_illumination
# ...
